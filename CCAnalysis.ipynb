# %%
# !pip install numpy pandas seaborn xlrd
# Out:
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.9/site-packages (1.20.3)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: seaborn in /opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: xlrd in /opt/anaconda3/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: matplotlib>=2.2 in /opt/anaconda3/lib/python3.9/site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)

# %%
# Import basic libraries
import numpy as np 
import pandas as pd 
# import visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('./datasets/default_credit.xls')
df.head(5)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 25 columns]

# %%
df.sample(7)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 3988    3989     300000    1          3         2   64     -1     -1     -1
# 7879    7880     240000    2          2         1   44      0      0      0
# 26890  26891     320000    1          2         2   32      0      0      0
# 14904  14905     180000    2          1         2   40      0      0      0
# 14667  14668      80000    1          2         1   57      0      0      0
# 27422  27423     170000    1          2         2   31      0     -1      0
# 19555  19556     300000    2          2         1   28      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 3988      -1  ...       1372       1610       1355      1168      1005
# 7879       2  ...     232995     206167     210100      9657     19253
# 26890     -1  ...     167983     142305     153555     10454     80003
# 14904      0  ...      46121      95432      50984      1800      2000
# 14667      0  ...      57601      58807      60300      2007      2047
# 27422      0  ...     192082     120077      92593    168019      5000
# 19555     -1  ...      28960      26589      18171      1373      1010
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 3988       1372      1610      1355      1426                           0
# 7879          0      7641      7522      7949                           0
# 26890    174169     10000     15013      1770                           0
# 14904      2000      2332      5000      1000                           0
# 14667      2060      2133      2469      2493                           0
# 27422      6000      7125      5000      4500                           0
# 19555     42348         0         0       173                           0
#
# [7 rows x 25 columns]

# %%
# Getting Meta Data Information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default payment next month  30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %%
df.describe().T
# Out:
#                               count           mean            std       min  \
# ID                          30000.0   15000.500000    8660.398374       1.0
# LIMIT_BAL                   30000.0  167484.322667  129747.661567   10000.0
# SEX                         30000.0       1.603733       0.489129       1.0
# EDUCATION                   30000.0       1.853133       0.790349       0.0
# MARRIAGE                    30000.0       1.551867       0.521970       0.0
# AGE                         30000.0      35.485500       9.217904      21.0
# PAY_0                       30000.0      -0.016700       1.123802      -2.0
# PAY_2                       30000.0      -0.133767       1.197186      -2.0
# PAY_3                       30000.0      -0.166200       1.196868      -2.0
# PAY_4                       30000.0      -0.220667       1.169139      -2.0
# PAY_5                       30000.0      -0.266200       1.133187      -2.0
# PAY_6                       30000.0      -0.291100       1.149988      -2.0
# BILL_AMT1                   30000.0   51223.330900   73635.860576 -165580.0
# BILL_AMT2                   30000.0   49179.075167   71173.768783  -69777.0
# BILL_AMT3                   30000.0   47013.154800   69349.387427 -157264.0
# BILL_AMT4                   30000.0   43262.948967   64332.856134 -170000.0
# BILL_AMT5                   30000.0   40311.400967   60797.155770  -81334.0
# BILL_AMT6                   30000.0   38871.760400   59554.107537 -339603.0
# PAY_AMT1                    30000.0    5663.580500   16563.280354       0.0
# PAY_AMT2                    30000.0    5921.163500   23040.870402       0.0
# PAY_AMT3                    30000.0    5225.681500   17606.961470       0.0
# PAY_AMT4                    30000.0    4826.076867   15666.159744       0.0
# PAY_AMT5                    30000.0    4799.387633   15278.305679       0.0
# PAY_AMT6                    30000.0    5215.502567   17777.465775       0.0
# default payment next month  30000.0       0.221200       0.415062       0.0
#
#                                  25%       50%        75%        max
# ID                           7500.75   15000.5   22500.25    30000.0
# LIMIT_BAL                   50000.00  140000.0  240000.00  1000000.0
# SEX                             1.00       2.0       2.00        2.0
# EDUCATION                       1.00       2.0       2.00        6.0
# MARRIAGE                        1.00       2.0       2.00        3.0
# AGE                            28.00      34.0      41.00       79.0
# PAY_0                          -1.00       0.0       0.00        8.0
# PAY_2                          -1.00       0.0       0.00        8.0
# PAY_3                          -1.00       0.0       0.00        8.0
# PAY_4                          -1.00       0.0       0.00        8.0
# PAY_5                          -1.00       0.0       0.00        8.0
# PAY_6                          -1.00       0.0       0.00        8.0
# BILL_AMT1                    3558.75   22381.5   67091.00   964511.0
# BILL_AMT2                    2984.75   21200.0   64006.25   983931.0
# BILL_AMT3                    2666.25   20088.5   60164.75  1664089.0
# BILL_AMT4                    2326.75   19052.0   54506.00   891586.0
# BILL_AMT5                    1763.00   18104.5   50190.50   927171.0
# BILL_AMT6                    1256.00   17071.0   49198.25   961664.0
# PAY_AMT1                     1000.00    2100.0    5006.00   873552.0
# PAY_AMT2                      833.00    2009.0    5000.00  1684259.0
# PAY_AMT3                      390.00    1800.0    4505.00   896040.0
# PAY_AMT4                      296.00    1500.0    4013.25   621000.0
# PAY_AMT5                      252.50    1500.0    4031.50   426529.0
# PAY_AMT6                      117.75    1500.0    4000.00   528666.0
# default payment next month      0.00       0.0       0.00        1.0

# %%
# Checking for Null Values 
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
print('SEX ' + str(sorted(df['SEX'].unique())))
# Out:
# SEX [1, 2]

# %%
print('EDUCATION ' + str(sorted(df['EDUCATION'].unique())))
# Out:
# EDUCATION [0, 1, 2, 3, 4, 5, 6]

# %%
print('MARRIAGE ' + str(sorted(df['MARRIAGE'].unique())))
# Out:
# MARRIAGE [0, 1, 2, 3]

# %%
print('PAY_0 ' + str(sorted(df['PAY_0'].unique())))
# Out:
# PAY_0 [-2, -1, 0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
print('default payment next month' + str(sorted(df['default payment next month'].unique())))
# Out:
# default payment next month[0, 1]

# %%
fill = (df.EDUCATION == 0) | (df.EDUCATION == 5)| (df.EDUCATION == 6)
df.loc[fill, 'EDUCATION'] = 4

# %%
print('EDUCATION ' + str(sorted(df['EDUCATION'].unique())))
# Out:
# EDUCATION [1, 2, 3, 4]

# %%
fill = (df.MARRIAGE == 0)
df.loc[fill, 'MARRIAGE'] = 2

# %%
df = df.rename(columns={'default payment next month': 'DEFAULT', 'PAY_0': 'PAY_1'})
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 0         0         0         0        1
# 1      1000         0      2000        1
# 2      1000      1000      5000        0
# 3      1100      1069      1000        0
# 4      9000       689       679        0
#
# [5 rows x 25 columns]

# %%
# Univariate Analysis

# %%
sns.countplot(x="DEFAULT", data=df)
# Out:
# <AxesSubplot:xlabel='DEFAULT', ylabel='count'>

# %%
df['DEFAULT'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: DEFAULT, dtype: int64

# %%
sns.countplot(x="SEX", data=df)
# Out:
# <AxesSubplot:xlabel='SEX', ylabel='count'>

# %%
df['SEX'].value_counts()
# Out:
# 2    18112
# 1    11888
# Name: SEX, dtype: int64

# %%
sns.countplot(x="EDUCATION", data=df)
# Out:
# <AxesSubplot:xlabel='EDUCATION', ylabel='count'>

# %%
df['EDUCATION'].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 4      468
# Name: EDUCATION, dtype: int64

# %%
sns.countplot(x="MARRIAGE", data=df)
# Out:
# <AxesSubplot:xlabel='MARRIAGE', ylabel='count'>

# %%
df['MARRIAGE'].value_counts()
# Out:
# 2    16018
# 1    13659
# 3      323
# Name: MARRIAGE, dtype: int64

# %%
# Bivariate

# %%
sns.set(rc={'figure.figsize':(15,10)})
edu = sns.countplot(x='SEX', hue='DEFAULT', data=df)
edu.set_xticklabels(['Male','Female'])
plt.show()

# %%
pd.crosstab(df.SEX,df.DEFAULT,normalize='index',margins=True)
# Out:
# DEFAULT         0         1
# SEX
# 1        0.758328  0.241672
# 2        0.792237  0.207763
# All      0.778800  0.221200

# %%
sns.set(rc={'figure.figsize':(15,10)})
edu = sns.countplot(x='EDUCATION', hue='DEFAULT', data=df)
edu.set_xticklabels(['Graduate School','University','High School','Other'])
plt.show()

# %%
pd.crosstab(df.EDUCATION,df.DEFAULT,normalize='index')
# Out:
# DEFAULT           0         1
# EDUCATION
# 1          0.807652  0.192348
# 2          0.762651  0.237349
# 3          0.748424  0.251576
# 4          0.929487  0.070513

# %%
sns.set(rc={'figure.figsize':(12,10)})
marriage = sns.countplot(x="MARRIAGE", hue='DEFAULT', data=df)
marriage.set_xticklabels(['Married','Single','Other'])
plt.show()

# %%
pd.crosstab(df.MARRIAGE,df.DEFAULT,normalize='index',margins=True)
# Out:
# DEFAULT          0         1
# MARRIAGE
# 1         0.765283  0.234717
# 2         0.791110  0.208890
# 3         0.739938  0.260062
# All       0.778800  0.221200

# %%
pd.crosstab(df.PAY_1,df.DEFAULT,margins=True)
# Out:
# DEFAULT      0     1    All
# PAY_1
# -2        2394   365   2759
# -1        4732   954   5686
# 0        12849  1888  14737
# 1         2436  1252   3688
# 2          823  1844   2667
# 3           78   244    322
# 4           24    52     76
# 5           13    13     26
# 6            5     6     11
# 7            2     7      9
# 8            8    11     19
# All      23364  6636  30000

# %%
sns.catplot(x="DEFAULT", y="LIMIT_BAL", jitter=True, data=df);

# %%
pd.crosstab(df.AGE,df.DEFAULT)
# Out:
# DEFAULT     0    1
# AGE
# 21         53   14
# 22        391  169
# 23        684  247
# 24        827  300
# 25        884  302
# 26       1003  253
# 27       1164  313
# 28       1123  286
# 29       1292  313
# 30       1121  274
# 31        988  229
# 32        933  225
# 33        931  215
# 34        931  231
# 35        887  226
# 36        854  254
# 37        812  229
# 38        750  194
# 39        755  199
# 40        683  187
# 41        639  185
# 42        609  185
# 43        520  150
# 44        538  162
# 45        501  116
# 46        413  157
# 47        381  120
# 48        362  104
# 49        333  119
# 50        310  101
# 51        252   88
# 52        226   78
# 53        251   74
# 54        191   56
# 55        152   57
# 56        129   49
# 57         95   27
# 58         91   31
# 59         62   21
# 60         44   23
# 61         35   21
# 62         37    7
# 63         23    8
# 64         22    9
# 65         19    5
# 66         18    7
# 67         11    5
# 68          4    1
# 69         12    3
# 70          8    2
# 71          3    0
# 72          2    1
# 73          1    3
# 74          1    0
# 75          2    1
# 79          1    0

# %%
pd.crosstab(df.AGE,df.DEFAULT,normalize='index',margins=True)
# Out:
# DEFAULT         0         1
# AGE
# 21       0.791045  0.208955
# 22       0.698214  0.301786
# 23       0.734694  0.265306
# 24       0.733807  0.266193
# 25       0.745363  0.254637
# 26       0.798567  0.201433
# 27       0.788084  0.211916
# 28       0.797019  0.202981
# 29       0.804984  0.195016
# 30       0.803584  0.196416
# 31       0.811832  0.188168
# 32       0.805699  0.194301
# 33       0.812391  0.187609
# 34       0.801205  0.198795
# 35       0.796945  0.203055
# 36       0.770758  0.229242
# 37       0.780019  0.219981
# 38       0.794492  0.205508
# 39       0.791405  0.208595
# 40       0.785057  0.214943
# 41       0.775485  0.224515
# 42       0.767003  0.232997
# 43       0.776119  0.223881
# 44       0.768571  0.231429
# 45       0.811994  0.188006
# 46       0.724561  0.275439
# 47       0.760479  0.239521
# 48       0.776824  0.223176
# 49       0.736726  0.263274
# 50       0.754258  0.245742
# 51       0.741176  0.258824
# 52       0.743421  0.256579
# 53       0.772308  0.227692
# 54       0.773279  0.226721
# 55       0.727273  0.272727
# 56       0.724719  0.275281
# 57       0.778689  0.221311
# 58       0.745902  0.254098
# 59       0.746988  0.253012
# 60       0.656716  0.343284
# 61       0.625000  0.375000
# 62       0.840909  0.159091
# 63       0.741935  0.258065
# 64       0.709677  0.290323
# 65       0.791667  0.208333
# 66       0.720000  0.280000
# 67       0.687500  0.312500
# 68       0.800000  0.200000
# 69       0.800000  0.200000
# 70       0.800000  0.200000
# 71       1.000000  0.000000
# 72       0.666667  0.333333
# 73       0.250000  0.750000
# 74       1.000000  0.000000
# 75       0.666667  0.333333
# 79       1.000000  0.000000
# All      0.778800  0.221200

# %%
#Correlation

# %%
df.corr()
# Out:
#                  ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE  \
# ID         1.000000   0.026179  0.018497   0.037659 -0.028689  0.018678
# LIMIT_BAL  0.026179   1.000000  0.024755  -0.231088 -0.110788  0.144713
# SEX        0.018497   0.024755  1.000000   0.013627 -0.029675 -0.090874
# EDUCATION  0.037659  -0.231088  0.013627   1.000000 -0.141852  0.182434
# MARRIAGE  -0.028689  -0.110788 -0.029675  -0.141852  1.000000 -0.415478
# AGE        0.018678   0.144713 -0.090874   0.182434 -0.415478  1.000000
# PAY_1     -0.030575  -0.271214 -0.057643   0.112593  0.019137 -0.039447
# PAY_2     -0.011215  -0.296382 -0.070771   0.129703  0.023972 -0.050148
# PAY_3     -0.018494  -0.286123 -0.066096   0.122425  0.032712 -0.053048
# PAY_4     -0.002735  -0.267460 -0.060173   0.116531  0.032477 -0.049722
# PAY_5     -0.022199  -0.249411 -0.055064   0.104088  0.035027 -0.053826
# PAY_6     -0.020270  -0.235195 -0.044008   0.088986  0.033784 -0.048773
# BILL_AMT1  0.019389   0.285430 -0.033642   0.016597 -0.026554  0.056239
# BILL_AMT2  0.017982   0.278314 -0.031183   0.011980 -0.024223  0.054283
# BILL_AMT3  0.024354   0.283236 -0.024563   0.006714 -0.027875  0.053710
# BILL_AMT4  0.040351   0.293988 -0.021880  -0.006131 -0.026136  0.051353
# BILL_AMT5  0.016705   0.295562 -0.017005  -0.012439 -0.028163  0.049345
# BILL_AMT6  0.016730   0.290389 -0.016733  -0.012646 -0.023937  0.047613
# PAY_AMT1   0.009742   0.195236 -0.000242  -0.041088 -0.005129  0.026147
# PAY_AMT2   0.008406   0.178408 -0.001391  -0.032793 -0.009099  0.021785
# PAY_AMT3   0.039151   0.210167 -0.008597  -0.044293 -0.004040  0.029247
# PAY_AMT4   0.007793   0.203242 -0.002229  -0.040949 -0.013623  0.021379
# PAY_AMT5   0.000652   0.217202 -0.001667  -0.045138 -0.002430  0.022850
# PAY_AMT6   0.003000   0.219595 -0.002766  -0.044061 -0.007854  0.019478
# DEFAULT   -0.013952  -0.153520 -0.039961   0.033842 -0.026672  0.013890
#
#               PAY_1     PAY_2     PAY_3     PAY_4  ...  BILL_AMT4  BILL_AMT5  \
# ID        -0.030575 -0.011215 -0.018494 -0.002735  ...   0.040351   0.016705
# LIMIT_BAL -0.271214 -0.296382 -0.286123 -0.267460  ...   0.293988   0.295562
# SEX       -0.057643 -0.070771 -0.066096 -0.060173  ...  -0.021880  -0.017005
# EDUCATION  0.112593  0.129703  0.122425  0.116531  ...  -0.006131  -0.012439
# MARRIAGE   0.019137  0.023972  0.032712  0.032477  ...  -0.026136  -0.028163
# AGE       -0.039447 -0.050148 -0.053048 -0.049722  ...   0.051353   0.049345
# PAY_1      1.000000  0.672164  0.574245  0.538841  ...   0.179125   0.180635
# PAY_2      0.672164  1.000000  0.766552  0.662067  ...   0.222237   0.221348
# PAY_3      0.574245  0.766552  1.000000  0.777359  ...   0.227202   0.225145
# PAY_4      0.538841  0.662067  0.777359  1.000000  ...   0.245917   0.242902
# PAY_5      0.509426  0.622780  0.686775  0.819835  ...   0.271915   0.269783
# PAY_6      0.474553  0.575501  0.632684  0.716449  ...   0.266356   0.290894
# BILL_AMT1  0.187068  0.234887  0.208473  0.202812  ...   0.860272   0.829779
# BILL_AMT2  0.189859  0.235257  0.237295  0.225816  ...   0.892482   0.859778
# BILL_AMT3  0.179785  0.224146  0.227494  0.244983  ...   0.923969   0.883910
# BILL_AMT4  0.179125  0.222237  0.227202  0.245917  ...   1.000000   0.940134
# BILL_AMT5  0.180635  0.221348  0.225145  0.242902  ...   0.940134   1.000000
# BILL_AMT6  0.176980  0.219403  0.222327  0.239154  ...   0.900941   0.946197
# PAY_AMT1  -0.079269 -0.080701  0.001295 -0.009362  ...   0.233012   0.217031
# PAY_AMT2  -0.070101 -0.058990 -0.066793 -0.001944  ...   0.207564   0.181246
# PAY_AMT3  -0.070561 -0.055901 -0.053311 -0.069235  ...   0.300023   0.252305
# PAY_AMT4  -0.064005 -0.046858 -0.046067 -0.043461  ...   0.130191   0.293118
# PAY_AMT5  -0.058190 -0.037093 -0.035863 -0.033590  ...   0.160433   0.141574
# PAY_AMT6  -0.058673 -0.036500 -0.035861 -0.026565  ...   0.177637   0.164184
# DEFAULT    0.324794  0.263551  0.235253  0.216614  ...  -0.010156  -0.006760
#
#            BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# ID          0.016730  0.009742  0.008406  0.039151  0.007793  0.000652
# LIMIT_BAL   0.290389  0.195236  0.178408  0.210167  0.203242  0.217202
# SEX        -0.016733 -0.000242 -0.001391 -0.008597 -0.002229 -0.001667
# EDUCATION  -0.012646 -0.041088 -0.032793 -0.044293 -0.040949 -0.045138
# MARRIAGE   -0.023937 -0.005129 -0.009099 -0.004040 -0.013623 -0.002430
# AGE         0.047613  0.026147  0.021785  0.029247  0.021379  0.022850
# PAY_1       0.176980 -0.079269 -0.070101 -0.070561 -0.064005 -0.058190
# PAY_2       0.219403 -0.080701 -0.058990 -0.055901 -0.046858 -0.037093
# PAY_3       0.222327  0.001295 -0.066793 -0.053311 -0.046067 -0.035863
# PAY_4       0.239154 -0.009362 -0.001944 -0.069235 -0.043461 -0.033590
# PAY_5       0.262509 -0.006089 -0.003191  0.009062 -0.058299 -0.033337
# PAY_6       0.285091 -0.001496 -0.005223  0.005834  0.019018 -0.046434
# BILL_AMT1   0.802650  0.140277  0.099355  0.156887  0.158303  0.167026
# BILL_AMT2   0.831594  0.280365  0.100851  0.150718  0.147398  0.157957
# BILL_AMT3   0.853320  0.244335  0.316936  0.130011  0.143405  0.179712
# BILL_AMT4   0.900941  0.233012  0.207564  0.300023  0.130191  0.160433
# BILL_AMT5   0.946197  0.217031  0.181246  0.252305  0.293118  0.141574
# BILL_AMT6   1.000000  0.199965  0.172663  0.233770  0.250237  0.307729
# PAY_AMT1    0.199965  1.000000  0.285576  0.252191  0.199558  0.148459
# PAY_AMT2    0.172663  0.285576  1.000000  0.244770  0.180107  0.180908
# PAY_AMT3    0.233770  0.252191  0.244770  1.000000  0.216325  0.159214
# PAY_AMT4    0.250237  0.199558  0.180107  0.216325  1.000000  0.151830
# PAY_AMT5    0.307729  0.148459  0.180908  0.159214  0.151830  1.000000
# PAY_AMT6    0.115494  0.185735  0.157634  0.162740  0.157834  0.154896
# DEFAULT    -0.005372 -0.072929 -0.058579 -0.056250 -0.056827 -0.055124
#
#            PAY_AMT6   DEFAULT
# ID         0.003000 -0.013952
# LIMIT_BAL  0.219595 -0.153520
# SEX       -0.002766 -0.039961
# EDUCATION -0.044061  0.033842
# MARRIAGE  -0.007854 -0.026672
# AGE        0.019478  0.013890
# PAY_1     -0.058673  0.324794
# PAY_2     -0.036500  0.263551
# PAY_3     -0.035861  0.235253
# PAY_4     -0.026565  0.216614
# PAY_5     -0.023027  0.204149
# PAY_6     -0.025299  0.186866
# BILL_AMT1  0.179341 -0.019644
# BILL_AMT2  0.174256 -0.014193
# BILL_AMT3  0.182326 -0.014076
# BILL_AMT4  0.177637 -0.010156
# BILL_AMT5  0.164184 -0.006760
# BILL_AMT6  0.115494 -0.005372
# PAY_AMT1   0.185735 -0.072929
# PAY_AMT2   0.157634 -0.058579
# PAY_AMT3   0.162740 -0.056250
# PAY_AMT4   0.157834 -0.056827
# PAY_AMT5   0.154896 -0.055124
# PAY_AMT6   1.000000 -0.053183
# DEFAULT   -0.053183  1.000000
#
# [25 rows x 25 columns]

# %%
sns.set(rc={'figure.figsize':(30,10)})
sns.set_context("talk", font_scale=0.7)

# %%
sns.heatmap(df.iloc[:,1:].corr(method='spearman'), cmap='rainbow_r', annot=True)
# Out:
# <AxesSubplot:>
