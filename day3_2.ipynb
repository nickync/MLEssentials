# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%2010%20-%20Analyzing%20a%20Dataset/Datasets/bikes.csv'

df = pd.read_csv(url)

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.describe().T
# Out:
#               count        mean         std   min      25%      50%       75%  \
# season      10886.0    2.506614    1.116174  1.00   2.0000    3.000    4.0000
# holiday     10886.0    0.028569    0.166599  0.00   0.0000    0.000    0.0000
# workingday  10886.0    0.680875    0.466159  0.00   0.0000    1.000    1.0000
# weather     10886.0    1.418427    0.633839  1.00   1.0000    1.000    2.0000
# temp        10886.0   20.230860    7.791590  0.82  13.9400   20.500   26.2400
# atemp       10886.0   23.655084    8.474601  0.76  16.6650   24.240   31.0600
# humidity    10886.0   61.886460   19.245033  0.00  47.0000   62.000   77.0000
# windspeed   10886.0   12.799395    8.164537  0.00   7.0015   12.998   16.9979
# casual      10886.0   36.021955   49.960477  0.00   4.0000   17.000   49.0000
# registered  10886.0  155.552177  151.039033  0.00  36.0000  118.000  222.0000
# count       10886.0  191.574132  181.144454  1.00  42.0000  145.000  284.0000
#
#                  max
# ...

# %%
df.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
df.sample(10)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 8976  2012-08-16 09:00:00       3        0           1        1  29.52
# 5543  2012-01-06 02:00:00       1        0           1        1   9.02
# 1917  2011-05-06 19:00:00       2        0           1        3  22.14
# 1030  2011-03-07 11:00:00       1        0           1        1  10.66
# 4862  2011-11-15 16:00:00       4        0           1        2  21.32
# 2471  2011-06-10 21:00:00       2        0           1        1  31.16
# 3385  2011-08-10 23:00:00       3        0           1        1  30.34
# 8141  2012-06-19 14:00:00       2        0           1        1  31.16
# 6146  2012-02-12 08:00:00       1        0           0        1   3.28
# 3818  2011-09-10 02:00:00       3        0           0        2  24.60
#
#        atemp  humidity  windspeed  casual  registered  count
# 8976  33.335        54     7.0015      41         296    337
# 5543  11.365        69    11.0014       2           3      5
# ...

# %%
sns.barplot(x='weather', y='count',data=df)
plt.show()

# %%
ax = sns.lmplot(x='temp',y='count',data=df,hue='season')
plt.show()

# %%
df.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
#
#             humidity  windspeed    casual  registered     count
# ...

# %%
#sns.heatmap(df[:,1:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/hn/3wwh9yy571jbqjltnqglztg80000gn/T/ipykernel_12064/1779166483.py in <module>
# ----> 1 sns.heatmap(df[:,1:])
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# ...

# %%
(df['casual'] + df['registered'] == df['count']).unique().sum()
# Out:
# 1

# %%
sns.lmplot(x='workingday', y='count', data=df)

# %%
df.dtypes
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object
